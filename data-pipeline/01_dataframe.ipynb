# %%
import pandas as pd

# %%
df = pd.DataFrame(
    columns=["Name", "Age", "Height"],
)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Name, Age, Height]
# Index: []

# %%
df.loc[0] = ["Allen", 25, 175]

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   25     175

# %%
df.loc[1] = ["Bob", 30, 180]
df.loc[2] = ["Cathy", 28, 165]

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   25     175
# 1    Bob   30     180
# 2  Cathy   28     165

# %%
df["Weight"] = [70, 80, 60]

# %%
df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   25     175      70
# 1    Bob   30     180      80
# 2  Cathy   28     165      60

# %%
df.drop("Weight", axis=1)
# Out:
#     Name  Age  Height
# 0  Allen   25     175
# 1    Bob   30     180
# 2  Cathy   28     165

# %%
df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   25     175      70
# 1    Bob   30     180      80
# 2  Cathy   28     165      60

# %%
df = df.drop("Weight", axis=1)
df
# Out:
#     Name  Age  Height
# 0  Allen   25     175
# 1    Bob   30     180
# 2  Cathy   28     165

# %%
df.drop(2)
# Out:
#     Name  Age  Height
# 0  Allen   25     175
# 1    Bob   30     180

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   25     175
# 1    Bob   30     180
# 2  Cathy   28     165

# %%
df = df.drop(2)

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   25     175
# 1    Bob   30     180

# %%
df["Height"][0]
# Out:
# np.int64(175)

# %%
df["Height"][0] = 178
# Out:
# /var/folders/_k/k5dry95j0q5d35_9pn5d86vm0000gn/T/ipykernel_10678/1784337542.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Height"][0] = 178
# ...

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   25     178
# 1    Bob   30     180

# %%
df.loc[0, "Height"]
# Out:
# np.int64(178)

# %%
df.loc[0, "Height"] = 179

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   25     179
# 1    Bob   30     180

# %%
df.loc[0:1, "Age":"Height"]
# Out:
#    Age  Height
# 0   25     179
# 1   30     180

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   25     179
# 1    Bob   30     180

# %%
"""
select
    Name
    , Age
    , Height
from df2
"""
data = [
    ["Allen", 25, 175],
    ["Bob", 30, 180],
    ["Cathy", 28, 165],
]
columns = ["Name", "Age", "Height"]
df2 = pd.DataFrame(data, columns=columns)

# %%
df2
# Out:
#     Name  Age  Height
# 0  Allen   25     175
# 1    Bob   30     180
# 2  Cathy   28     165

# %%
"""
select * from df
union all
select * from df2
"""
pd.concat(
    [df, df2],
    ignore_index=True,
)
# Out:
#     Name  Age  Height
# 0  Allen   25     179
# 1    Bob   30     180
# 2  Allen   25     175
# 3    Bob   30     180
# 4  Cathy   28     165

# %%
df["Age"]
# Out:
# 0    25
# 1    30
# Name: Age, dtype: int64

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   25     179
# 1    Bob   30     180

# %%
df.to_json(
    "df.json",
)

# %%
df.to_json(
    "df_columns.json",
    orient="columns",
    indent=4,
)

# %%
df.to_json(
    "df_records.json",
    orient="records",
    indent=4,
)

# %%
df.to_json(
    "df_records.jsonl",
    orient="records",
    lines=True,
)

# %%
df.to_json(
    "df_index.json",
    orient="index",
    indent=4,
)

# %%
df.to_json(
    "df_split.json",
    orient="split",
    indent=4,
)

# %%
df.to_json(
    "df_table.json",
    orient="table",
    indent=4,
)

# %%
df_with_col = pd.read_csv(
    "ptt.csv",
)

df_with_col
# Out:
#           推      噓       分數                               作者  \
# 0     推: 25   噓: 4   分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     推: 11  噓: 11    分數: 0            作者: LoveMakeLove (ボケ)
# 2     推: 20   噓: 0   分數: 20               作者: MintSu (Simon)
# 3     推: 31   噓: 2   分數: 29               作者: seiya2000 (風見)
# 4    推: 106   噓: 6  分數: 100               作者: kasumi5566 (霞)
# ..      ...    ...      ...                              ...
# 833   推: 10   噓: 1    分數: 9              作者: lockgolden (鎖金)
# 834    推: 7   噓: 0    分數: 7           作者: nothisman (在人海中迷失)
# 835    推: 0   噓: 0    分數: 0      作者: wa778895 (oilsunbright)
# 836   推: 15   噓: 4   分數: 11              作者: stan0720 (Kimo)
# 837    推: 5   噓: 0    分數: 5           作者: bigtreelife (Tree)
#
#                                  標題                            時間
# 0       標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020
# 1      標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020
# ...

# %%
df_no_col = pd.read_csv(
    "ptt_no_col.csv",
    header=None,
    names=["推", "噓", "分數", "作者", "標題", "時間"],
)

df_no_col
# Out:
#           推      噓       分數                               作者  \
# 0     推: 25   噓: 4   分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     推: 11  噓: 11    分數: 0            作者: LoveMakeLove (ボケ)
# 2     推: 20   噓: 0   分數: 20               作者: MintSu (Simon)
# 3     推: 31   噓: 2   分數: 29               作者: seiya2000 (風見)
# 4    推: 106   噓: 6  分數: 100               作者: kasumi5566 (霞)
# ..      ...    ...      ...                              ...
# 833   推: 10   噓: 1    分數: 9              作者: lockgolden (鎖金)
# 834    推: 7   噓: 0    分數: 7           作者: nothisman (在人海中迷失)
# 835    推: 0   噓: 0    分數: 0      作者: wa778895 (oilsunbright)
# 836   推: 15   噓: 4   分數: 11              作者: stan0720 (Kimo)
# 837    推: 5   噓: 0    分數: 5           作者: bigtreelife (Tree)
#
#                                  標題                            時間
# 0       標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020
# 1      標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020
# ...

# %%
df_no_col = pd.read_csv(
    "ptt_no_col.csv",
    header=None,
)

df_no_col.columns = ["推", "噓", "分數", "作者", "標題", "時間"]

df_no_col
# Out:
#           推      噓       分數                               作者  \
# 0     推: 25   噓: 4   分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     推: 11  噓: 11    分數: 0            作者: LoveMakeLove (ボケ)
# 2     推: 20   噓: 0   分數: 20               作者: MintSu (Simon)
# 3     推: 31   噓: 2   分數: 29               作者: seiya2000 (風見)
# 4    推: 106   噓: 6  分數: 100               作者: kasumi5566 (霞)
# ..      ...    ...      ...                              ...
# 833   推: 10   噓: 1    分數: 9              作者: lockgolden (鎖金)
# 834    推: 7   噓: 0    分數: 7           作者: nothisman (在人海中迷失)
# 835    推: 0   噓: 0    分數: 0      作者: wa778895 (oilsunbright)
# 836   推: 15   噓: 4   分數: 11              作者: stan0720 (Kimo)
# 837    推: 5   噓: 0    分數: 5           作者: bigtreelife (Tree)
#
#                                  標題                            時間
# 0       標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020
# 1      標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020
# ...
