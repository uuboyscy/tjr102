# %%
import pandas as pd
from pandasql import sqldf

file_path_staff = "staff.csv"
file_path_staff_samecol = "staff_samecol.csv"
file_path_staff_detail = "staff_detail.csv"
file_path_staff_detail_different_col = "staff_detail_different_col.csv"

df_staff = pd.read_csv(file_path_staff)
df_staff_samecol = pd.read_csv(file_path_staff_samecol)
df_staff_detail = pd.read_csv(file_path_staff_detail)
df_staff_detail_different_col = pd.read_csv(file_path_staff_detail_different_col)

# %%
df_staff
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
sql = "select * from df_staff"
sqldf(sql)
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
sql = """
    select
        d.ID
        , d.Level
        , dim.Gender
    from df_staff_detail d
    left join df_staff dim
    on d.ID = dim.ID
"""
sqldf(sql)
# Out:
#     ID Level Gender
# 0    1     A      M
# 1    1     S      M
# 2    2     A      F
# 3    3     A      M
# 4    3     S      M
# 5    4     A      M
# 6    5     A      M
# 7    5     S      M
# 8    6     A      F
# 9    7     A      M
# 10   7     S      M
# 11   7     M      M
# 12   8     A      F
# 13   8     S      F
# 14   8     M      F

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'df_staff',
#   'import pandas as pd\nfrom pandasql import sqldf\n\nfile_path_staff = "staff.csv"\nfile_path_staff_samecol = "staff_samecol.csv"\nfile_path_staff_detail = "staff_detail.csv"\nfile_path_staff_detail_different_col = "staff_detail_different_col.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_samecol = pd.read_csv(file_path_staff_samecol)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)\ndf_staff_detail_different_col = pd.read_csv(file_path_staff_detail_different_col)',
#   'df_staff',
#   'sql = "select * from df_staff"\nsqldf(sql)',
#   'sql = """\n    select *\n    from df_staff_detail d\n    left join df_staff dim\n    on d.ID = dim.ID\n"""\nsqldf(sql)',
# ...

# %%
globals()["df_staff"]
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'df_staff',
#   'import pandas as pd\nfrom pandasql import sqldf\n\nfile_path_staff = "staff.csv"\nfile_path_staff_samecol = "staff_samecol.csv"\nfile_path_staff_detail = "staff_detail.csv"\nfile_path_staff_detail_different_col = "staff_detail_different_col.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_samecol = pd.read_csv(file_path_staff_samecol)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)\ndf_staff_detail_different_col = pd.read_csv(file_path_staff_detail_different_col)',
#   'df_staff',
#   'sql = "select * from df_staff"\nsqldf(sql)',
#   'sql = """\n    select *\n    from df_staff_detail d\n    left join df_staff dim\n    on d.ID = dim.ID\n"""\nsqldf(sql)',
# ...
